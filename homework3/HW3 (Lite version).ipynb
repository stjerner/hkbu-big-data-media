# %%
import pandas as pd
from pandas import Series,DataFrame
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Official Singles Chart Top 100.csv")

# %%
df['companys'].value_counts()[:10].plot(kind='bar')

# %% [markdown]
# We can see the most popular 100 songs, nearly a third were published by these three record labels: 'INTERSCOPE', 'POLYDOR', 'ATLANTIC'. The most interesting part of the 'company' part is that the whole chart is published by 'Official Charts Company' which belongs to the 'Entertainment Retailers Association' in the UK, however, the top three companies are all belongs to the US (although 'POLYDOR' located in London, it is a subsidiary of American 'INTERSCOPE' ).

# %%
# !pip3 install plotly

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)
from plotly.offline import iplot
from plotly.graph_objs import Bar
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
df_top10_artists = df['artists'].value_counts()[:10]

iplot({
    "data": [Bar(x=df_top10_artists.index, y=df_top10_artists.values)],
    "layout": Layout(title="Top 10 Artists")
})
# Out:
# <div id="7e539915-54ec-4af2-8bf6-ea79bca2ac44" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7e539915-54ec-4af2-8bf6-ea79bca2ac44", [{"type": "bar", "x": ["XXXTENTACION", "GEORGE EZRA", "WEEKND", "ED SHEERAN", "DUA LIPA", "SHAWN MENDES", "POST MALONE", "POST MALONE FT TY DOLLA SIGN", "CRAIG DAVID FT BASTILLE", "SHAKKA FT ALUNAGEORGE"], "y": [3, 3, 3, 3, 2, 2, 1, 1, 1, 1]}], {"title": "Top 10 Artists"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# the most popular four artists are 'XXXTENTATION','ED SHEERAN','GEORGE EZRA' and 'WEEKND'. Two of them are native singers(ed sheeran and george ezra). And all of them are very young, they all born in or after 1990.

# %%
from collections import Counter
c = Counter()
df['titles'].apply(lambda x: c.update(set(x.split())))
c
# Out:
# Counter({'(FIFTY': 1,
#          '(REMIX)': 1,
#          '(SATURDAY': 1,
#          '-': 1,
#          '17': 1,
#          '2': 1,
#          'A': 2,
#          'ALIVE': 1,
#          'ALL': 1,
#          'AMEN': 1,
#          'ANSWERPHONE': 1,
#          'ANYWHERE': 1,
#          'APART': 1,
#          'ARE': 1,
#          'AT': 1,
#          'BACK': 2,
#          'BAD': 1,
#          'BARKING': 1,
#          'BE': 3,
#          'BELIEVER': 1,
#          'BLINDED': 1,
#          'BLOOD': 1,
#          'BREATHE': 1,
#          'BRIGHTSIDE': 1,
#          'BY': 1,
#          'CALL': 1,
#          'CAME': 1,
#          'CAPITAL': 1,
#          'CAREFUL': 1,
#          'CHANGES': 1,
#          'CHECK': 1,
#          'CIGARETTE': 1,
#          'DAYS': 1,
#          'DEAD': 1,
#          'DELICATE': 1,
#          'DESPACITO': 1,
#          'DO': 1,
#          'DONE': 1,
#          'DOWN': 3,
#          'DREAMS': 1,
#          'DRIP': 1,
#          'ENOUGH': 1,
#          'EVERYDAY': 1,
#          'EXCUSES': 1,
#          'FALL': 1,
#          'FEEL': 1,
#          'FINE': 1,
#          'FINESSE': 1,
#          'FIRST': 1,
#          'FLAIR': 1,
#          'FLAMES': 1,
#          'FLOWERS': 1,
#          'FOR': 3,
#          'FORGET': 1,
#          'FREAKY': 1,
#          'FREED)': 1,
#          'FRIDAY': 1,
#          'FRIENDS': 1,
#          'GO': 1,
#          "GOD'S": 1,
#          'GOOD': 1,
#          'GOODBYES': 1,
#          'GRACE': 1,
#          'HANGMAN': 1,
#          'HAVANA': 1,
#          'HERE': 1,
#          'I': 5,
#          'IDGAF': 1,
#          'IN': 2,
#          'IS': 1,
#          'IT': 3,
#          'JAPAN': 1,
#          'JUMANJI': 1,
#          "KING'S": 1,
#          'KNOW': 1,
#          'LET': 2,
#          'LETTERS': 1,
#          'LIES': 1,
#          'LIKE': 1,
#          'LINE': 1,
#          'LOCATION': 1,
#          'LOOK': 1,
#          'LOST': 1,
#          'LOVE': 4,
#          'LOVER': 1,
#          'LULLABY': 1,
#          'MAD': 1,
#          'MAN': 1,
#          'ME': 5,
#          'MEANT': 1,
#          'MIDDLE': 1,
#          'MILLION': 1,
#          'MIMI': 1,
#          'MIND': 1,
#          'MINE': 1,
#          'MISS': 1,
#          'MOONLIGHT': 1,
#          'MR': 1,
#          'MY': 4,
#          'NAME': 1,
#          'NEVER': 2,
#          'NEW': 1,
#          'NIGHT)': 1,
#          'NO': 1,
#          'OF': 1,
#          'ON': 1,
#          'OUT': 1,
#          'PARADISE': 1,
#          'PEOPLE': 1,
#          'PERFECT': 1,
#          'PERSONAL': 1,
#          'PLAN': 1,
#          'PLUG': 1,
#          'PRETTY': 1,
#          'PSYCHO': 1,
#          'PT': 1,
#          'RAPPER': 1,
#          'REASON': 1,
#          'REMIND': 1,
#          'RIC': 1,
#          'RIVER': 1,
#          'ROCKSTAR': 1,
#          'RULES': 1,
#          'SAD': 1,
#          'SAME': 1,
#          'SANCTIFY': 1,
#          'SAY': 2,
#          'SHADES': 1,
#          'SHAPE': 1,
#          'SHINING': 1,
#          'SHOTGUN': 1,
#          'SILENCE': 1,
#          'SIT': 1,
#          'SOMETHING': 1,
#          'STARS': 1,
#          'STILL': 1,
#          'STRANGERS': 1,
#          'SUPERMARKET': 1,
#          'SYMPHONY': 1,
#          'TALK': 1,
#          'THE': 4,
#          'THESE': 1,
#          'THIS': 1,
#          'THOUSAND': 1,
#          'TIME': 1,
#          'TIMES': 1,
#          'TIP': 1,
#          'TO': 2,
#          'TOE': 1,
#          'TOO': 1,
#          'TRY': 1,
#          'UNFORGETTABLE': 1,
#          'VIBE': 1,
#          'VROOM': 1,
#          'WALK': 2,
#          'WANNA': 1,
#          'WANT': 1,
#          'WASTED': 1,
#          'WAVEY': 1,
#          'WAY': 1,
#          'WHAT': 1,
#          'WILD': 1,
#          'YEARS': 1,
#          'YES': 1,
#          'YOU': 7,
#          'YOUR': 1})

# %%
from wordcloud import WordCloud
wc = WordCloud()

# %%
w = wc.generate_from_frequencies(c)

# %%
import matplotlib.pyplot as plt
plt.imshow(w)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Of the 100 most popular titles, ‘ME’, ‘MY’, ‘I’ and ‘YOU’ have the highest frequency. And the most frequent word represents the emotion is ‘LOVE’. It is not difficult to tell those songs caring about people and expressing love are more popular.
